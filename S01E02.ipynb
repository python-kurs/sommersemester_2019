# %% [markdown]
# <img src="images/header.png" style="float: left"  width="800">

# %% [markdown]
# # Session 2 - Python Basics I

# %% [markdown]
# ## Hello world!

# %%
print("Hello world!")
# Out:
# Hello world!
